# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


import os
import glob
path = 'c:\\'
extension = 'csv'
os.chdir(path= "/Users/noahlevi/MegaHand-1/Models")
models = [i for i in glob.glob('*.{}'.format(extension))]
print(models)
# Out:
# ['int_MinMax_kbest_GBC.csv', 'RobustScaler_iPCA_RFC.csv', 'MinMaxScaler_PCA_GaussianNB.csv', 'robustscaler_ipca_gbc.csv', 'RobustScaler_PCA_GaussianNB.csv', 'RobustScaler_iPCA_GaussianNB.csv', 'int_robustscaler_ipca_GBC.csv', 'StandardScaler_PCA_GaussianNB.csv', 'int_robust_lSVC.csv', 'robustscaler_ipca_LogReg.csv', 'int_ipca_GBC.csv']

# %%
data=pd.read_csv('int_MinMax_kbest_GBC.csv').iloc[0:15,0:2]
print(data)
plt.bar(data['Unnamed: 0'], data["precision"])
plt.xlabel('Grip')
plt.ylabel('precision')
plt.xticks(rotation=85)
plt.show()
# Out:
#         Unnamed: 0  precision
# 0       Chuck Grip   0.786672
# 1       Fine Pinch   0.217191
# 2          H. Open   0.160934
# 3        Hook Grip   0.367127
# 4         Key Grip   0.131883
# 5          No Move   0.865611
# 6       Power Grip   0.150229
# 7   Thumb Enclosed   0.197356
# 8        Tool Grip   0.384178
# 9     W. Abduction   0.283197
# 10    W. Adduction   0.526305
# 11    W. Extension   0.519241
# 12      W. Flexion   0.669922
# 13    W. Pronation   0.599070
# 14   W. Supination   0.399877

# %%
# Out:
#         Unnamed: 0  precision
# 0       Chuck Grip   0.786672
# 1       Fine Pinch   0.217191
# 2          H. Open   0.160934
# 3        Hook Grip   0.367127
# 4         Key Grip   0.131883
# 5          No Move   0.865611
# 6       Power Grip   0.150229
# 7   Thumb Enclosed   0.197356
# 8        Tool Grip   0.384178
# 9     W. Abduction   0.283197
# 10    W. Adduction   0.526305
# 11    W. Extension   0.519241
# 12      W. Flexion   0.669922
# 13    W. Pronation   0.599070
# 14   W. Supination   0.399877
# 15       macro avg   0.417253
# 16       micro avg   0.395699
# 17    weighted avg   0.417253
